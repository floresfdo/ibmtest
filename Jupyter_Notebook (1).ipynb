# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fernando Flores**
# Staff Data Analyst

# %% [markdown]
# *I am interested in data science because I find automating complex calculations and processes interesting, as well as determining predective models.

# %% [markdown]
# ### My code below should perform arithmetic calculations in the correct order.

# %%
2*(4+2)
# Out:
# 12

# %% [markdown]
# ***
# 1. ~~Peer grading is fun
# 2. Hope you give me a passing grade
# 3. Thank you!
#
# ![294-2944056_thumbs-up-cartoon-spongebob-pixshark-spongebob-squarepants.png](attachment:ef9f2f60-dedc-40a2-afe9-f72169adc9cc.png)
